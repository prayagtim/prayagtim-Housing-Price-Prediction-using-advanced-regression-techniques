# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,StandardScaler
import seaborn as sns
from sklearn import datasets, ensemble

# %%
df=pd.read_csv('Housingart_train.csv')
df_test=pd.read_csv('Housingart_test.csv')
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
#deleting columns with correlation less than 0.05
df.drop(columns=['MiscFeature','Fence','PoolQC','Alley','BsmtExposure'],inplace=True)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
Encoder=LabelEncoder()

# %%
df['Street'].value_counts()
# Out:
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64

# %%
df['MasVnrType'].fillna(df['MasVnrType'].mode()[0],inplace=True)

# %%
df['MasVnrArea'].fillna(df['MasVnrArea'].interpolate(),inplace=True)

# %%
df['BsmtQual'].fillna(df['BsmtQual'].mode()[0],inplace=True)
df['BsmtQual'].value_counts()
# Out:
# TA    686
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
df['BsmtCond'].fillna('TA',inplace=True)
df['BsmtCond'].value_counts()
# Out:
# TA    1348
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64

# %%
df['BsmtFinType1'].value_counts()
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %%
df['BsmtFinType1'].isna().sum()
# Out:
# 37

# %%
df['BsmtFinType1'].fillna('GLQ',inplace=True)
df['BsmtFinType2'].fillna('GLQ',inplace=True)

# %%
df['GarageType'].value_counts()
df['GarageType'].fillna('Attchd',inplace=True)

# %%
df['GarageYrBlt'].fillna(df['GarageYrBlt'].mode()[0],inplace=True)
df['GarageFinish'].fillna(df['GarageFinish'].mode()[0],inplace=True)
df['GarageQual'].fillna(df['GarageQual'].mode()[0],inplace=True)
df['GarageCond'].fillna(df['GarageCond'].mode()[0],inplace=True)
df['Electrical'].fillna(df['Electrical'].mode()[0],inplace=True)

# %%
df['FireplaceQu'].fillna(df['FireplaceQu'].mode()[0],inplace=True)
df['LotFrontage'].fillna(df['LotFrontage'].mean(),inplace=True)

# %%
df_test.drop(columns=['MiscFeature','Fence','PoolQC','Alley','BsmtExposure'],inplace=True)

# %%
df_test['LotFrontage'].fillna(df_test['LotFrontage'].interpolate(),inplace=True)
df_test['FireplaceQu'].fillna(df_test['FireplaceQu'].mode()[0],inplace=True)
df_test['GarageYrBlt'].fillna(df_test['GarageYrBlt'].mode()[0],inplace=True)
df_test['GarageFinish'].fillna(df_test['GarageFinish'].mode()[0],inplace=True)
df_test['GarageQual'].fillna(df_test['GarageQual'].mode()[0],inplace=True)
df_test['GarageCond'].fillna(df_test['GarageCond'].mode()[0],inplace=True)
df_test['Electrical'].fillna(df_test['Electrical'].mode()[0],inplace=True)
df_test['BsmtQual'].fillna(df_test['BsmtQual'].mode()[0],inplace=True)
df_test['MasVnrArea'].fillna(df_test['MasVnrArea'].interpolate(),inplace=True)

# %%
df_test['GarageType'].fillna(df_test['GarageType'].mode()[0],inplace=True)
df_test['BsmtCond'].fillna(df_test['BsmtCond'].mode()[0],inplace=True)
df_test['BsmtFinType1'].fillna(df_test['BsmtFinType2'].mode()[0],inplace=True)
df_test['BsmtFinType2'].fillna(df_test['BsmtFinType2'].mode()[0],inplace=True)
df_test['MasVnrType'].fillna(df_test['MasVnrType'].mode()[0],inplace=True)

# %%
df_test['MSZoning'].fillna(df_test['MSZoning'].mode()[0],inplace=True)
df_test['SaleType'].fillna(df_test['SaleType'].mode()[0],inplace=True)
df_test['GarageCars'].fillna(df_test['GarageCars'].interpolate(),inplace=True)
df_test['GarageArea'].fillna(df_test['GarageArea'].interpolate(),inplace=True)
df_test['KitchenQual'].fillna(df_test['KitchenQual'].mode()[0],inplace=True)
df_test['Functional'].fillna(df_test['Functional'].mode()[0],inplace=True)
df_test['BsmtFullBath'].fillna(df_test['BsmtFullBath'].interpolate(),inplace=True)
df_test['BsmtHalfBath'].fillna(df_test['BsmtHalfBath'].interpolate(),inplace=True)
df_test['Utilities'].fillna(df_test['Utilities'].mode()[0],inplace=True)
df_test['Exterior1st'].fillna(df_test['Exterior1st'].mode()[0],inplace=True)
df_test['Exterior2nd'].fillna(df_test['Exterior2nd'].mode()[0],inplace=True)
df_test['BsmtFinSF1'].fillna(df_test['BsmtFinSF1'].interpolate(),inplace=True)
df_test['BsmtFinSF2'].fillna(df_test['BsmtFinSF2'].interpolate(),inplace=True)
df_test['BsmtUnfSF'].fillna(df_test['BsmtUnfSF'].interpolate(),inplace=True)
df_test['TotalBsmtSF'].fillna(df_test['TotalBsmtSF'].interpolate(),inplace=True)

# %%
sns.heatmap(df.isnull())

# %%
k=[df,df_test]
overall=pd.DataFrame(pd.concat(k))

# %%
overall
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
overall['YearBuilt']=2005-overall['YearBuilt']
overall['YearRemodAdd']=2005-overall['YearRemodAdd']
overall['GarageYrBlt']=2005-overall['GarageYrBlt']
overall['YearRemodAdd']=2005-overall['YearRemodAdd']
overall['YrSold']=2010-overall['YrSold']

# %%
Categories=['MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1',
           'Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual',
           'ExterCond','Foundation','BsmtQual','BsmtCond','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir',
           'Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond',
           'PavedDrive','SaleType','SaleCondition']

# %%
for i in range(len(Categories)):
    overall[Categories[i]]=Encoder.fit_transform(overall[Categories[i]])

# %%
overall['YearRemodAdd']=2005-overall['YearRemodAdd']
overall.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3         65.0     8450       1         3
# 1   2          20         3         80.0     9600       1         3
# 2   3          60         3         68.0    11250       1         0
# 3   4          70         3         60.0     9550       1         0
# 4   5          60         3         84.0    14260       1         0
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            3          0          4          0             5           2
# 1            3          0          2          0            24           1
# 2            3          0          4          0             5           2
# 3            3          0          0          0             6           2
# 4            3          0          2          0            15           2
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_train=overall.iloc[:1460,:]
df_test=overall.iloc[1460:,:]

# %%
df_train.corr()
# Out:
#                      Id  MSSubClass  MSZoning   LotFrontage   LotArea  \
# Id             1.000000    0.011156 -0.006096 -9.600822e-03 -0.033226
# MSSubClass     0.011156    1.000000  0.035900 -3.570559e-01 -0.139781
# MSZoning      -0.006096    0.035900  1.000000 -1.063635e-01 -0.034452
# LotFrontage   -0.009601   -0.357056 -0.106363  1.000000e+00  0.306795
# LotArea       -0.033226   -0.139781 -0.034452  3.067946e-01  1.000000
# Street         0.008916   -0.024969  0.087654 -3.732277e-02 -0.197131
# LotShape       0.032122    0.119289  0.061887 -1.449309e-01 -0.165315
# LandContour   -0.019659   -0.002940 -0.017854 -7.564653e-02 -0.149083
# Utilities      0.013324   -0.022844 -0.001192  5.171411e-18  0.010123
# LotConfig      0.049756    0.075910 -0.009895 -1.812535e-01 -0.121161
# LandSlope      0.005847   -0.025672 -0.022055  6.760810e-02  0.436868
# Neighborhood  -0.013735   -0.005985 -0.249679  8.454536e-02  0.044569
# ...

# %%
df_train.drop(columns=['Condition2','MasVnrType','BsmtFinSF2','LowQualFinSF','BsmtHalfBath','3SsnPorch','MiscVal','YrSold'],inplace=True)
df_test.drop(columns=['Condition2','MasVnrType','BsmtFinSF2','LowQualFinSF','BsmtHalfBath','3SsnPorch','MiscVal','YrSold'],inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
X=df_train.loc[:,'MSSubClass':'SaleCondition']
Xtest=df_test.loc[:,'MSSubClass':'SaleCondition']
np.array(X)
np.array(Xtest)
Y=df_train['SalePrice']
Y=np.array(Y)
re=ensemble.GradientBoostingRegressor(alpha=0.9,learning_rate=0.3)
re.fit(X,Y)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.3, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
re.score(X,Y)
# Out:
# 0.9847775493934176

# %%
k=re.predict(Xtest)

# %%
for i in range(len(result)):
    print(result[i])
# Out:
# 123030.65867311567
# 159182.68357042826
# 176460.69442921103
# 183751.8290930057
# 198398.2568028701
# 174488.4434910634
# 166859.71569385627
# 162480.1974944701
# 183832.24588007721
# 127746.05523143834
# 209442.0321325712
# 97444.80793917
# 94593.25894617842
# 152888.19534410554
# 137469.1003126136
# 411888.2701880378
# 258642.4759944458
# 306169.33588237455
# 285233.0567264966
# 471181.53312203445
# 315131.613191012
# 211210.8159994931
# 167014.1790133488
# 171705.117184611
# 185313.444584157
# 190072.45713911066
# 363639.18437586207
# 238769.54377125227
# 200156.6969405593
# 228618.57880588833
# 188438.80067358754
# 92186.96543978814
# 187412.84358661692
# 307377.64513854776
# 286129.6101021591
# 229177.6827462519
# 181724.32732134286
# 167478.91583338246
# 169454.60039999892
# 148753.59199983877
# 164972.9366755653
# 162637.02575199518
# 294645.4839984785
# 230306.42133099167
# 222980.11312721533
# 187281.37844045451
# 235871.36394263932
# 193886.3110896368
# 163192.67850414955
# ...

# %%
k=ensemble.RandomForestClassifier()
k.fit(X,Y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
k.score(X,Y)
# Out:
# 0.9993150684931507

# %%
pl=k.predict(Xtest)

# %%
for i in range(len(pl)):
    print(pl[i])
# Out:
# 144000.0
# 181900.0
# 192000.0
# 192000.0
# 153900.0
# 188000.0
# 173000.0
# 177000.0
# 173000.0
# 97000.0
# 278000.0
# 83000.0
# 88000.0
# 148500.0
# 133000.0
# 611657.0
# 233170.0
# 255500.0
# 147000.0
# 466500.0
# 305000.0
# 202500.0
# 200141.0
# 160200.0
# 184100.0
# 183500.0
# 275000.0
# 232000.0
# 208300.0
# 197000.0
# 180000.0
# 67000.0
# 145000.0
# 290000.0
# 348000.0
# 172500.0
# 216000.0
# 151000.0
# 151000.0
# 147400.0
# 176000.0
# 148800.0
# 394432.0
# 226000.0
# 189000.0
# 180500.0
# 260000.0
# 190000.0
# 140000.0
# 167500.0
# 140000.0
# 167000.0
# 170000.0
# 136500.0
# 140000.0
# 97500.0
# 140000.0
# 124000.0
# 220000.0
# 141000.0
# 139000.0
# 167500.0
# 115000.0
# 120000.0
# 122000.0
# 115000.0
# 105000.0
# 120000.0
# 132500.0
# 170000.0
# 135000.0
# 87000.0
# 130000.0
# 115000.0
# 125500.0
# 119000.0
# 60000.0
# 189950.0
# 140000.0
# 122000.0
# 140000.0
# 125500.0
# 210000.0
# 68500.0
# 119000.0
# 131000.0
# 119000.0
# 103600.0
# 133900.0
# 145000.0
# 91000.0
# ...
